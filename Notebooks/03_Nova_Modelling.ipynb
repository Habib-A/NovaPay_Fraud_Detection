# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/Nova_CleanedEDA_df.csv")

# Print the top 5 rows
df.head()
# Out:
#                          transaction_id                           customer_id  \
# 0  fee8542d-8ee6-4b0d-9671-c294dd08ed26  402cccc9-28de-45b3-9af7-cc5302aa1f93
# 1  bfdb9fc1-27fe-4a85-b043-4d813d679259  67c2c6b3-ef0a-4777-a3f1-c84a851bb6ad
# 2  fc855034-3ea5-4993-9afa-b511d93fe5e8  6d0d9b27-fa26-45f8-93b1-2df29d182d9c
# 3  2cf8c08e-42ec-444d-a755-34b9a2a0a4ca  7bd5200c-5d19-44f0-9afe-8b339a05366b
# 4  d907a74d-b426-438d-97eb-dbe911aca91c  70a93d26-8e3a-4179-900c-a4a7a74d08e5
#
#                           timestamp home_country source_currency  \
# 0  2022-10-03 18:40:59.468549+00:00           US             USD
# 1  2022-10-03 20:39:38.468549+00:00           CA             CAD
# 2  2022-10-03 23:02:43.468549+00:00           US             USD
# 3  2022-10-04 01:08:53.468549+00:00           US             USD
# 4  2022-10-04 09:35:03.468549+00:00           US             USD
#
#   dest_currency channel  amount_src  amount_usd   fee  ...  hour day_of_week  \
# 0           CAD     ATM      278.19      278.19  4.25  ...    18           0
# 1           MXN     WEB      208.51      154.29  4.24  ...    20           0
# 2           CNY  MOBILE      160.33      160.33  2.70  ...    23           0
# 3           EUR  MOBILE       59.41       59.41  2.22  ...     1           1
# 4           INR  MOBILE      200.96      200.96  3.61  ...     9           1
#
#    is_weekend is_night device_trust_bucket  ip_risk_bucket  amount_bucket  \
# 0           0        0             0.5-0.7         Low<0.3       $100-500
# 1           0        0             0.3-0.5         0.5-0.7       $100-500
# 2           0        0            High>0.9         0.3-0.5       $100-500
# 3           0        0             0.5-0.7         0.5-0.7          <$100
# 4           0        0             0.7-0.9         Low<0.3       $100-500
#
#   age_bucket  fee_bucket  currency_pair
# 0   180-365d        $4-5        USD_CAD
# 1    Unknown        $4-5        CAD_MXN
# 2       >1yr        $2-3        USD_CNY
# 3    90-180d        $2-3        USD_EUR
# 4   180-365d        $3-4        USD_INR
#
# [5 rows x 36 columns]

# %%
num_cols = df.select_dtypes(include=['int64', 'float64', 'int32']).columns

# %%
skewness = df[num_cols].skew().sort_values(ascending=False)
skewness
# Out:
# amount_usd                   42.078303
# fee                          10.568489
# amount_src                    6.931244
# chargeback_history_count      5.719823
# txn_velocity_1h               3.260465
# txn_velocity_24h              2.954218
# is_fraud                      2.883685
# exchange_rate_src_to_dest     2.269927
# corridor_risk                 1.589152
# risk_score_internal           1.490007
# ip_risk_score                 1.094328
# is_weekend                    0.985237
# is_night                      0.876305
# account_age_days              0.788949
# hour                          0.007096
# day_of_week                   0.006225
# device_trust_score           -0.532897
# dtype: float64

# %%
high_skew = skewness[abs(skewness) > 1]
high_skew
# Out:
# amount_usd                   42.078303
# fee                          10.568489
# amount_src                    6.931244
# chargeback_history_count      5.719823
# txn_velocity_1h               3.260465
# txn_velocity_24h              2.954218
# is_fraud                      2.883685
# exchange_rate_src_to_dest     2.269927
# corridor_risk                 1.589152
# risk_score_internal           1.490007
# ip_risk_score                 1.094328
# dtype: float64
